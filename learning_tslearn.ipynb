# %%
import pandas as pd
import numpy as np
from tslearn.clustering import TimeSeriesKMeans, KShape, KernelKMeans
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
from netdata_pandas.data import get_data, get_chart_list
from am4894plots.plots import plot_lines, plot_lines_grid
from tslearn.clustering import TimeSeriesKMeans

# %%
from tslearn.utils import to_time_series_dataset
my_first_time_series = [1, 3, 4, 2]
my_second_time_series = [1, 2, 4, 2, 1]
formatted_dataset = to_time_series_dataset([my_first_time_series,
my_second_time_series])

# %%
data = pd.read_csv("../data/fifty_stocks.csv")

X_train = data.drop(columns=['DATE'])

X_train = X_train.fillna(X_train.mean())



seed = 0
np.random.seed(seed)


X_train = X_train.T
X_train = TimeSeriesScalerMeanVariance().fit_transform(X_train)

# %%
# Author: Romain Tavenard
# License: BSD 3 clause

import numpy
import matplotlib.pyplot as plt

from tslearn.clustering import KShape
from tslearn.datasets import CachedDatasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
from tslearn.metrics import cdist_dtw
from tslearn.clustering import silhouette_score

import seaborn as sns



# sz = X_train.shape[1]

# kShape clustering

for test in range(2,10):
    
    ks = KShape(n_clusters=test, verbose=True, random_state=seed)
    y_pred = ks.fit_predict(X_train)

    score = silhouette_score(X_train, y_pred, metric="euclidean")

    print(f'This is the silhoutte score: {score} for custer {test}')

plt.figure()
# plt.style.use('dark_background')
for yi in range(3):
    plt.figure(figsize=(8, 6))
#     plt.subplot(3, 1, 1 + yi)
    for xx in X_train[y_pred == yi]:
        plt.plot(xx.ravel(), alpha=.2,color='green')
    plt.plot(ks.cluster_centers_[yi].ravel(), "r-")
#     plt.xlim(0, sz)
    plt.ylim(-10, 10)
    plt.title("Cluster %d" % (yi + 1))

# plt.tight_layout()
plt.show()
# Out:
# 0.123 --> 0.120 --> 0.119 --> 0.119 -->
# This is the silhoutte score: 0.23366008101322755 for custer 2
# 0.102 --> 0.094 --> 0.091 --> 0.091 -->
# This is the silhoutte score: 0.17054080810932606 for custer 3
# Resumed because of empty cluster
# 0.107 --> 0.088 --> 0.083 --> 0.083 --> 0.083 --> 0.083 --> 0.083 -->
# This is the silhoutte score: 0.14619617142022576 for custer 4
# Resumed because of empty cluster
# 0.062 --> 0.052 --> 0.051 --> 0.051 --> 0.051 -->
# This is the silhoutte score: 0.10643943122993867 for custer 5
# Resumed because of empty cluster
# 0.044 --> 0.043 --> 0.043 -->
# This is the silhoutte score: 0.11434845227462065 for custer 6
# Resumed because of empty cluster
# Resumed because of empty cluster
# 0.058 --> 0.048 --> 0.043 --> 0.043 --> 0.043 -->
# This is the silhoutte score: 0.0769536437908683 for custer 7
# Resumed because of empty cluster
# Resumed because of empty cluster
# 0.043 --> 0.042 --> 0.042 -->
# ...

# %%
import numpy
import matplotlib.pyplot as plt

from tslearn.clustering import KShape
from tslearn.datasets import CachedDatasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
from tslearn.metrics import cdist_dtw
from tslearn.clustering import silhouette_score
import seaborn as sns
    
ks = KShape(n_clusters=2, verbose=True, random_state=seed)
y_pred = ks.fit_predict(X_train)

score = silhouette_score(X_train, y_pred, metric="euclidean")

print(f'This is the silhoutte score: {score}')

plt.figure()
# plt.style.use('dark_background')
for yi in range(2):
    plt.figure(figsize=(8, 6))
#     plt.subplot(3, 1, 1 + yi)
    for xx in X_train[y_pred == yi]:
        plt.plot(xx.ravel(), alpha=.2,color='green')
    plt.plot(ks.cluster_centers_[yi].ravel(), "r-")
#     plt.xlim(0, sz)s
    plt.ylim(-10, 10)
    plt.title("Cluster %d" % (yi + 1))
    plt.grid(axis='x', color='0.95')


# plt.tight_layout()
plt.show()
# Out:
# 0.123 --> 0.120 --> 0.119 --> 0.119 -->
# This is the silhoutte score: 0.23366008101322755

# %%
Cluster_1= ['ULTRACEMO', 'POWERGRID']
Cluster_2= ['SBIN', 'ICICIBANK', 'AXISBANK']
Cluster_3=[ 'NESTLEIND', 'HINDUNILVR']
Cluster_4= ['RELIANCE', 'SHREECEM', 'M&M', 'MARUTI', 'INDUSBANK', 'HEROMOTOCO', 'HDFC', 'BPCL', 'BRITANNIA', 
              'BAJAJFINSERV', 'BHARTIARTL', 'BAJAJ-AUTO']
Cluster_5= ['TATASTEEL', 'ONGC', 'JSWSTEEL', 'KOTAKBANK', 'HINDALCO']
Cluster_6= ['WIPRO', 'TECHM', 'TCS', 'INFY', 'HCLTECH']
Cluster_7= ['TITAN', 'TATAMOTORS', 'HDFCBANK']
Cluster_8= ['DRREDDYS', 'CIPLA']
Cluster_9= ['ITC', 'GRASIM', 'BAJAJFINANCE']
Cluster_10= ['NTPC', 'LT', 'IOC', 'EICHERMOTOR', 'COALINDIA', 'ASIANPAINT']

# %%
data = pd.read_csv("../data/fifty_stocks.csv")

X_train = data.drop(columns=['DATE'])

X_train = X_train.fillna(X_train.mean())

train1 = X_train[Cluster_1]
train2 = X_train[Cluster_2]
train3 = X_train[Cluster_3]
train4 = X_train[Cluster_4]
train5 = X_train[Cluster_5]
train6 = X_train[Cluster_6]
train7 = X_train[Cluster_7]
train8 = X_train[Cluster_8]
train9 = X_train[Cluster_9]
train10 = X_train[Cluster_10]


train1 = train1.T
train2 = train2.T
train3 = train3.T
train4 = train4.T
train5 = train5.T
train6 = train6.T
train7 = train7.T
train8 = train8.T
train9 = train9.T
train10 = train10.T


# seed = 0
# np.random.seed(seed)


# X_train = X_train.T
train1 = TimeSeriesScalerMeanVariance().fit_transform(train1)
train2 = TimeSeriesScalerMeanVariance().fit_transform(train2)
train3 = TimeSeriesScalerMeanVariance().fit_transform(train3)
train4 = TimeSeriesScalerMeanVariance().fit_transform(train4)
train5 = TimeSeriesScalerMeanVariance().fit_transform(train5)
train6 = TimeSeriesScalerMeanVariance().fit_transform(train6)
train7 = TimeSeriesScalerMeanVariance().fit_transform(train7)
train8 = TimeSeriesScalerMeanVariance().fit_transform(train8)
train9 = TimeSeriesScalerMeanVariance().fit_transform(train9)
train10 = TimeSeriesScalerMeanVariance().fit_transform(train10)

# %%
from tslearn.clustering import KShape
from tslearn.datasets import CachedDatasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
from tslearn.metrics import cdist_dtw
from tslearn.clustering import silhouette_score
import seaborn as sns

clust = 2
ks = KShape(n_clusters=clust, verbose=True, random_state=seed)
y_pred = ks.fit_predict(train4)

score = silhouette_score(train4, y_pred, metric="euclidean")

print(f'This is the silhoutte score: {score}')

dtws = dtw_score(train4, y_pred)

print(f'DTW SCORE {dtws}')

plt.figure()
# plt.style.use('dark_background')
for yi in range(clust):
    plt.figure(figsize=(8, 6))
#     plt.subplot(3, 1, 1 + yi)
    for xx in train4[y_pred == yi]:
        plt.plot(xx.ravel(), alpha=.2,color='green')
    plt.plot(ks.cluster_centers_[yi].ravel(), "r-")
#     plt.xlim(0, sz)s
    plt.ylim(-10, 10)
    plt.title("Cluster %d" % (yi + 1))
    plt.grid(axis='x', color='0.95')


# plt.tight_layout()
plt.show()
# Out:
# 0.050 --> 0.049 --> 0.049 --> 0.049 --> 0.049 --> 0.049 --> 0.049 --> 0.049 -->
# This is the silhoutte score: 0.1851393556936538
# DTW SCORE [[38.26202342]
#  [40.38386778]
#  [37.01281272]
#  [38.82358342]
#  [38.21821536]
#  [41.54642967]
#  [38.35991259]
#  [41.0408879 ]
#  [41.48719592]
#  [38.68613255]
#  [38.5630372 ]
#  [42.21587483]]

# %%
from tslearn.clustering import KShape
from tslearn.datasets import CachedDatasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
from tslearn.metrics import cdist_dtw as dtw_score
from tslearn.clustering import silhouette_score
import seaborn as sns

clust = 2
ks = KShape(n_clusters=clust, verbose=True, random_state=seed)
y_pred = ks.fit_predict(train10)

score = silhouette_score(train10, y_pred, metric="euclidean")
dtws = dtw_score(train10, y_pred)

print(f'DTW SCORE {dtws}')

print(f'This is the silhoutte score: {score}')

plt.figure()
# plt.style.use('dark_background')
for yi in range(clust):
    plt.figure(figsize=(8, 6))
#     plt.subplot(3, 1, 1 + yi)
    for xx in train10[y_pred == yi]:
        plt.plot(xx.ravel(), alpha=.2,color='green')
    plt.plot(ks.cluster_centers_[yi].ravel(), "r-")
#     plt.xlim(0, sz)s
    plt.ylim(-10, 10)
    plt.title("Cluster %d" % (yi + 1))
    plt.grid(axis='x', color='0.95')


# plt.tight_layout()
plt.show()
# Out:
# 0.056 --> 0.056 -->
# DTW SCORE [[46.03579717]
#  [48.12437788]
#  [42.20519703]
#  [39.79907656]
#  [46.22224887]
#  [38.88726546]]
# This is the silhoutte score: 0.14304883673104743

# %%
from tslearn.clustering import KShape
from tslearn.datasets import CachedDatasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
from tslearn.metrics import cdist_dtw
from tslearn.clustering import silhouette_score
import seaborn as sns

clust = 2
ks = KShape(n_clusters=clust, verbose=True, random_state=seed)
y_pred = ks.fit_predict(train5)

score = silhouette_score(train5, y_pred, metric="euclidean")

print(f'This is the silhoutte score: {score}')

dtws = dtw_score(train5, y_pred)

print(f'DTW SCORE {dtws}')


plt.figure()
# plt.style.use('dark_background')
for yi in range(clust):
    plt.figure(figsize=(8, 6))
#     plt.subplot(3, 1, 1 + yi)
    for xx in train5[y_pred == yi]:
        plt.plot(xx.ravel(), alpha=.2,color='green')
    plt.plot(ks.cluster_centers_[yi].ravel(), "r-")
#     plt.xlim(0, sz)s
    plt.ylim(-10, 10)
    plt.title("Cluster %d" % (yi + 1))
    plt.grid(axis='x', color='0.95')


# plt.tight_layout()
plt.show()
# Out:
# 0.075 --> 0.075 --> 0.075 --> 0.075 --> 0.075 --> 0.075 --> 0.075 --> 0.075 --> 0.075 --> 0.075 --> 0.074 --> 0.073 --> 0.073 --> 0.073 --> 0.073 --> 0.073 --> 0.073 --> 0.073 --> 0.073 --> 0.073 --> 0.073 --> 0.073 --> 0.073 --> 0.073 --> 0.073 --> 0.073 --> 0.073 --> 0.073 --> 0.073 --> 0.073 --> 0.072 --> 0.072 --> 0.072 --> 0.072 --> 0.072 --> 0.072 --> 0.072 --> 0.072 --> 0.072 --> 0.072 --> 0.072 --> 0.071 --> 0.071 --> 0.071 --> 0.071 --> 0.071 --> 0.071 --> 0.071 --> 0.071 --> 0.071 --> 0.071 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.070 --> 0.069 --> 0.069 --> 0.069 --> 0.069 --> 0.069 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --> 0.068 --
# ...

# %%
from tslearn.clustering import KShape
from tslearn.datasets import CachedDatasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
from tslearn.metrics import cdist_dtw
from tslearn.clustering import silhouette_score
import seaborn as sns

clust = 2
ks = KShape(n_clusters=clust, verbose=True, random_state=seed)
y_pred = ks.fit_predict(train6)

score = silhouette_score(train6, y_pred, metric="euclidean")

print(f'This is the silhoutte score: {score}')
dtws = dtw_score(train6, y_pred)

print(f'DTW SCORE {dtws}')

plt.figure()
# plt.style.use('dark_background')
for yi in range(clust):
    plt.figure(figsize=(8, 6))
#     plt.subplot(3, 1, 1 + yi)
    for xx in train6[y_pred == yi]:
        plt.plot(xx.ravel(), alpha=.2,color='green')
    plt.plot(ks.cluster_centers_[yi].ravel(), "r-")
#     plt.xlim(0, sz)s
    plt.ylim(-10, 10)
    plt.title("Cluster %d" % (yi + 1))
    plt.grid(axis='x', color='0.95')
    


# plt.tight_layout()
plt.show()
# Out:
# 0.035 --> 0.035 -->
# This is the silhoutte score: 0.13468424182728964
# DTW SCORE [[42.25376742]
#  [40.17031747]
#  [46.97737196]
#  [37.38313037]
#  [42.9807062 ]]

# %% [markdown]
# <h2> Results </h2>
#
# We are not having many results with our Kmeans clustering. We are now moving on to a bayes approach.
