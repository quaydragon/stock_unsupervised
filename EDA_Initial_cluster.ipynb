# %% [markdown]
# <h1> Project Milestone </h1>

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials

# %% [markdown]
# <h2> Data Cleaning </h2>
#
#
# Pull other data or find these companies.

# %%
fifty = pd.read_csv('../data/fifty_stocks.csv')

# %%
fifty.sort_values("DATE", ascending=False).head()
# Out:
#             DATE  TATASTEEL   WIPRO    TITAN  ULTRACEMO    TECHM  RELIANCE  \
# 2710  2021-10-14    1375.05  708.25  2564.05    7395.50  1430.80   2700.40
# 2709  2021-10-13    1354.30  672.60  2537.20    7350.40  1402.15   2694.95
# 2708  2021-10-08    1373.60  603.85  1799.20    7474.15  1323.05   2088.05
# 2707  2021-10-06    1114.45  554.25  1738.65    6709.65  1064.90   2183.00
# 2706  2021-10-05    1216.35  525.95  1455.15    6403.10   990.50   1926.20
#
#       SHREECEM  SUNPHARMA  TATAMOTORS  ...    BPCL  BRITANNIA  ADANIPORTS  \
# 2710  27956.45     841.30      497.60  ...  459.30    3894.85      812.80
# 2709  27815.70     842.55      506.90  ...  458.65    3883.70      759.00
# 2708  27117.65     793.35      294.20  ...  444.70    3637.20      693.00
# 2707  28225.80     676.05      344.75  ...  483.55    3576.30      846.75
# 2706  27309.95     698.20      314.85  ...  453.70    3413.80      765.45
#
#       BAJAJFINSERV  BAJAJFINANCE  BHARTIARTL  AXISBANK  BAJAJ-AUTO  \
# ...

# %% [markdown]
# <h2> Initial Understanding of the data </h2>
#
# This data consists of the prices of the stocks over the past ten years. This is generally good as a target data set but I think we can grab outside economic information that would allow us to better understand the data at each date.
#
# I think it is important to realize that these are target prices within this data.

# %%
mean_fifty = fifty.fillna(fifty.mean())

# %%
zero_fifty = fifty.fillna(0)

# %%
## We should be using 0 because it means they did not report the earnings

companies = zero_fifty.columns

# %%
## There are 47 of the companies
## grab in company information
### This is an example of what can be done 

tsla_df = yf.download('WIT', 
                      start='2019-01-01', 
                      end='2019-12-31', 
                      progress=False)
tsla_df.head()
# Out:
#             Open  High   Low  Close  Adj Close   Volume
# Date
# 2019-01-02  5.07  5.16  5.07   5.11   5.067266   466800
# 2019-01-03  5.07  5.09  5.02   5.05   5.007767   676500
# 2019-01-04  5.05  5.08  5.02   5.06   5.017683  1356100
# 2019-01-07  5.07  5.11  5.04   5.06   5.017683   659700
# 2019-01-08  5.07  5.11  5.04   5.11   5.067266   617100

# %%
## pulling in inflation / interest rate data 

inflation_interest = pd.read_csv('../data/inflation.csv')

# %%
inflation_interest[inflation_interest.Year >= 2010].head()
# Out:
#      Year  Month  Day  Federal Funds Target Rate  Federal Funds Upper Target  \
# 814  2010      1    1                        NaN                        0.25
# 815  2010      2    1                        NaN                        0.25
# 816  2010      3    1                        NaN                        0.25
# 817  2010      4    1                        NaN                        0.25
# 818  2010      5    1                        NaN                        0.25
#
#      Federal Funds Lower Target  Effective Federal Funds Rate  \
# 814                         0.0                          0.11
# 815                         0.0                          0.13
# 816                         0.0                          0.16
# 817                         0.0                          0.20
# 818                         0.0                          0.20
#
#      Real GDP (Percent Change)  Unemployment Rate  Inflation Rate
# ...

# %%
above_2010 = inflation_interest[inflation_interest.Year >= 2010]

# %%
### new dates mean fifty


def separate_dates(row):
    date
# Out:
# Index(['Year', 'Month', 'Day', 'Federal Funds Target Rate',
#        'Federal Funds Upper Target', 'Federal Funds Lower Target',
#        'Effective Federal Funds Rate', 'Real GDP (Percent Change)',
#        'Unemployment Rate', 'Inflation Rate'],
#       dtype='object')

# %% [markdown]
# Okay so now I am thinking of how am I going to make this company specific. What am I looking for? Im looking for similarities between these companies
#
#
# First I am going to apply the kmeans clustering algorithm, just to see where they are at. I think there should be a multi level approach at determing what clustering algorithm this should go into.

# %% [markdown]
# <h2> Kmeans Clustering Attempt </h2>
